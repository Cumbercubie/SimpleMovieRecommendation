# %%
import pandas as pd
# !pip install rake_nltk
from sklearn.metrics.pairwise import cosine_similarity
from sklearn.feature_extraction.text import CountVectorizer
from rake_nltk import Rake
rake = Rake()
# Out:
# Requirement already satisfied: rake_nltk in d:\python 3.7\lib\site-packages (1.0.4)
# Requirement already satisfied: nltk in d:\python 3.7\lib\site-packages (from rake_nltk) (3.5)
# Requirement already satisfied: click in d:\python 3.7\lib\site-packages (from nltk->rake_nltk) (7.0)
# Requirement already satisfied: joblib in d:\python 3.7\lib\site-packages (from nltk->rake_nltk) (0.14.1)
# Requirement already satisfied: regex in d:\python 3.7\lib\site-packages (from nltk->rake_nltk) (2020.6.8)
# Requirement already satisfied: tqdm in d:\python 3.7\lib\site-packages (from nltk->rake_nltk) (4.46.1)
# Could not build wheels for rake-nltk, since package 'wheel' is not installed.
# Could not build wheels for nltk, since package 'wheel' is not installed.
# Could not build wheels for click, since package 'wheel' is not installed.
# Could not build wheels for joblib, since package 'wheel' is not installed.
# Could not build wheels for regex, since package 'wheel' is not installed.
# Could not build wheels for tqdm, since package 'wheel' is not installed.
# WARNING: You are using pip version 20.1; however, version 20.1.1 is available.
# You should consider upgrading via the 'd:\python 3.7\python.exe -m pip install --upgrade pip' command.

# %%
ml_25 = pd.read_csv('10mil.csv')

# %%
data = ml_25[['title','director','cast','genres','overview']]
data.head(3)
# Out:
#               title       director  \
# 0         Toy Story  John Lasseter
# 1           Jumanji   Joe Johnston
# 2  Grumpier Old Men  Howard Deutch
#
#                                                 cast  \
# 0  Tom Hanks|Tim Allen|Don Rickles|Jim Varney|Wal...
# 1  Robin Williams|Jonathan Hyde|Kirsten Dunst|Bra...
# 2  Walter Matthau|Jack Lemmon|Ann-Margret|Sophia ...
#
#                      genres                                           overview
# 0   Animation|Comedy|Family  Woody the cowboy is young Andyâ€™s favorite to...
# 1  Adventure|Fantasy|Family  When siblings Judy and Peter discover an encha...
# 2            Romance|Comedy  A family wedding reignites the ancient feud be...

# %%
data['director'] = data['director'].fillna(' ')
data['director'] = data['director'].astype(str)
data['cast'] = data['cast'].fillna(' ')
data['cast'] = data['cast'].astype(str)
data['key_notes'] = ''
for index,row in data.iterrows():
    plot = str(row['overview'])
    rake.extract_keywords_from_text(plot)
    keyword_score = rake.get_word_degrees()
    genre = ' '.join(str(row['genres']).split('|')).lower()
    director = ' '.join(row['director'].replace(' ','').split('|')).lower()
    cast = ' '.join(row['cast'].replace(' ','').split('|')).lower()
    keyword_score = ' '.join(list(keyword_score.keys()))
    row['key_notes'] = genre + ' ' + ' ' + director + ' ' + cast + ' ' + keyword_score
recommend = data[['title','key_notes']]
recommend['key_notes']
# Out:
# D:\Python 3.7\lib\site-packages\ipykernel_launcher.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   """Entry point for launching an IPython kernel.
# D:\Python 3.7\lib\site-packages\ipykernel_launcher.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
# D:\Python 3.7\lib\site-packages\ipykernel_launcher.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   This is separate from the ipykernel package so we can avoid doing imports until
# D:\Python 3.7\lib\site-packages\ipykernel_launcher.py:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   after removing the cwd from sys.path.
# D:\Python 3.7\lib\site-packages\ipykernel_launcher.py:5: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   """
# 'animation comedy family  johnlasseter tomhanks timallen donrickles jimvarney wallaceshawn young andyâ €™ changes birthday revenge toy story use entirely computer animation longer number one plans yet andy get milestone film history favorite buzz first feature cowboy new super lightyear woody'

# %%
cv = CountVectorizer()
count_mat = cv.fit_transform(recommend['key_notes'])
cosine_sim = cosine_similarity(count_mat,count_mat)
print(cosine_sim)
# Out:
# [[1.         0.02354408 0.04819627 ... 0.03256448 0.02951407 0.08623253]
#  [0.02354408 1.         0.06978632 ... 0.         0.02849014 0.        ]
#  [0.04819627 0.06978632 1.         ... 0.03217447 0.02916059 0.03407991]
#  ...
#  [0.03256448 0.         0.03217447 ... 1.         0.03940552 0.04605313]
#  [0.02951407 0.02849014 0.02916059 ... 0.03940552 1.         0.        ]
#  [0.08623253 0.         0.03407991 ... 0.04605313 0.         1.        ]]

# %%
indices = pd.Series(recommend['title'])
def recommend_movie(name):
    movie=[]
    idx = indices[indices == name].index[0]
    sort_index = pd.Series(cosine_sim[idx]).sort_values(ascending = False)
    recommendation_5= sort_index.iloc[1:5]
    for i in recommendation_5.index:
        movie.append(indices[i])
    return movie

# %%
def rec():
    try:
        i = 1
        while(i > 0):
            name = input("Enter The Name of a Movie or Tv Show: ")
            if name.lower() == 'quit':
                break
            else:
                print(recommend_movie(name))

    except KeyboardInterrupt:
        print("The movie or Tv Show does not exist\n")
        rec()

    except IndexError:
        print("The movie or Tv Show does not exist\n")
        rec()
        

print("To exit Enter \"quit\" \n")
rec()
# Out:
# To exit Enter "quit"
#
# Enter The Name of a Movie or Tv Show: The Irishman
# The movie or Tv Show does not exist
#
# Enter The Name of a Movie or Tv Show: Toy Story
# ['Toy Story 2', "Doug's 1st Movie", 'Oliver & Company', 'American Pop']
# Enter The Name of a Movie or Tv Show: Jumanji
# ['MirrorMask', 'Bedknobs and Broomsticks', "Lemony Snicket's A Series of Unfortunate Events", 'Hook']

# %%
ml_25
# Out:
#        movieId                        title  \
# 0            1                    Toy Story
# 1            2                      Jumanji
# 2            3             Grumpier Old Men
# 3            4            Waiting to Exhale
# 4            5  Father of the Bride Part II
# ...        ...                          ...
# 10676    65088              Bedtime Stories
# 10677    65091          Manhattan Melodrama
# 10678    65126                        Choke
# 10679    65130           Revolutionary Road
# 10680    65133      Blackadder Back & Forth
#
#                                              Genre  year  \
# 0      Adventure|Animation|Children|Comedy|Fantasy  1995
# 1                       Adventure|Children|Fantasy  1995
# 2                                   Comedy|Romance  1995
# 3                             Comedy|Drama|Romance  1995
# 4                                           Comedy  1995
# ...                                            ...   ...
# 10676                    Adventure|Children|Comedy  2008
# 10677                          Crime|Drama|Romance  1934
# 10678                                 Comedy|Drama  2008
# 10679                                Drama|Romance  2008
# 10680                                       Comedy  1999
#
#                                                     cast         director  \
# 0      Tom Hanks|Tim Allen|Don Rickles|Jim Varney|Wal...    John Lasseter
# 1      Robin Williams|Jonathan Hyde|Kirsten Dunst|Bra...     Joe Johnston
# 2      Walter Matthau|Jack Lemmon|Ann-Margret|Sophia ...    Howard Deutch
# 3      Whitney Houston|Angela Bassett|Loretta Devine|...  Forest Whitaker
# 4      Steve Martin|Diane Keaton|Martin Short|Kimberl...    Charles Shyer
# ...                                                  ...              ...
# 10676  Adam Sandler|Keri Russell|Guy Pearce|Courteney...    Adam Shankman
# 10677                                               None             None
# 10678  Anjelica Huston|Kelly Macdonald|Sam Rockwell|C...      Clark Gregg
# 10679  Leonardo DiCaprio|Kate Winslet|Michael Shannon...       Sam Mendes
# 10680  Rowan Atkinson|Tony Robinson|Stephen Fry|Hugh ...     Paul Weiland
#
#                                                  tagline  \
# 0                               The adventure takes off!
# 1              Roll the dice and unleash the excitement!
# 2      Still Yelling. Still Fighting. Still Ready for...
# 3      Friends are the people who let you be yourself...
# 4      Just When His World Is Back To Normal... He's ...
# ...                                                  ...
# 10676       Whatever they dream up... he has to survive.
# 10677                                               None
# 10678                      From the author of Fight Club
# 10679      How do you break free without breaking apart?
# 10680  The final episode in the saga of the Blackadde...
#
#                                                 overview runtime  \
# 0      Woody the cowboy is young Andyâ€™s favorite to...    81.0
# 1      When siblings Judy and Peter discover an encha...   104.0
# 2      A family wedding reignites the ancient feud be...   101.0
# 3      Cheated on, mistreated and stepped on, the wom...   127.0
# 4      Just when George Banks has recovered from his ...   106.0
# ...                                                  ...     ...
# 10676  Skeeter Bronson is a down-on-his-luck guy who'...    99.0
# 10677                                               None    None
# 10678  A sex-addicted con-man pays for his mother's h...    92.0
# 10679  A young couple living in a Connecticut suburb ...   119.0
# 10680  It's Millennium Eve and Blackadder is hosting ...    33.0
#
#                               genres  \
# 0            Animation|Comedy|Family
# 1           Adventure|Fantasy|Family
# 2                     Romance|Comedy
# 3               Comedy|Drama|Romance
# 4                             Comedy
# ...                              ...
# 10676  Fantasy|Comedy|Family|Romance
# 10677                           None
# 10678                   Comedy|Drama
# 10679                  Drama|Romance
# 10680                 Comedy|History
#
#                                     production_companies
# 0           Walt Disney Pictures|Pixar Animation Studios
# 1      TriStar Pictures|Teitler Film|Interscope Commu...
# 2                            Warner Bros.|Lancaster Gate
# 3                 Twentieth Century Fox Film Corporation
# 4              Sandollar Productions|Touchstone Pictures
# ...                                                  ...
# 10676  Walt Disney Pictures|Happy Madison Productions...
# 10677                                               None
# 10678  Fox Searchlight Pictures|Contrafilm|ATO Pictur...
# 10679  DreamWorks SKG|Scott Rudin Productions|BBC Fil...
# 10680                    Tiger Aspect Productions|Sky TV
#
# [10681 rows x 11 columns]
